# %%
class Parent:
    def fun1(self):
       print("This function is belongs to Parent Class")

class Child(Parent):
    def fun2(self):
        print("This function is belongs to Child class")
object=Child()
object.fun1()
object.fun2()
# Out:
# This function is belongs to Parent Class
# This function is belongs to Child class

# %%
class Parent:
    def fun1(self):
        print("This Function belongs to Parent Class")
class Child(Parent):
    def fun1(self):
        print("This Function belongs to Child Class")
object=Child()
object.fun1()
# Out:
# This Function belongs to Child Class

# %%
class Animal:
    def fun1(self):
        print("This Function belongs to Animal Class")
class Human(Animal):
    def fun1(self):
        print("This Function belongs to Human Class")
object=Human()
object.fun1()
# Out:
# This Function belongs to Human Class
