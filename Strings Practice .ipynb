# %%
s='Akshaya'

# %%
name='Akshaya'
print(name)
# Out:
# Akshaya

# %%
name='Akshaya'
email='aksh@777'
print(name)
print(email)
# Out:
# Akshaya
# aksh@777

# %%
city='Busan'
print(city[3])
# Out:
# a

# %%
print(city[-3])
# Out:
# s

# %%
print(city[-5])
# Out:
# B

# %%
name='BehindTheScenes'
print(name[-5])
print(name[-8])
# Out:
# c
# h

# %%
name='JustinSeagull'
print(name[2:7])
# Out:
# stinS

# %%
name='JustinSeagull'
print(len(name))
# Out:
# 13

# %%
name1='Justin'
name2='Seagull'
print(name1+name2)
# Out:
# JustinSeagull

# %%
name='JustinSeagull'
print('JustinSeagull' * 7)
# Out:
# JustinSeagullJustinSeagullJustinSeagullJustinSeagullJustinSeagullJustinSeagullJustinSeagull

# %%
name='justinseagull'
print(name.upper())
# Out:
# JUSTINSEAGULL

# %%
city='JEJUISLAND'
print(city.lower())
# Out:
# jejuisland

# %%
s='I like Chocolates'
print(s.replace('Chocolates' , 'Icecreams'))
# Out:
# I like Icecreams

# %%
s='Icecream Chocolate'
print(s.find('Chocolate'))
# Out:
# 9

# %%
name=input("Enter the name :")
print("welcome",name)
