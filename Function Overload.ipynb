# %%
name=input("Enter Your Name")
print("Welcome",name)
# Out:
# Enter Your Name Akshaya
# Welcome Akshaya

# %%
ss="Behind"
print(ss[::-1])
# Out:
# dniheB

# %%
name='Serene'
def greet():
    print("Wassup" , name)

greet()
# Out:
# Wassup Serene

# %%
brand='Audi'
def car():
    print("The OG car is",brand)

car()
# Out:
# The OG car is Audi

# %%
def add(a,b):
    return a+b
print(add(7455,7647))
# Out:
# 15102

# %%
def add(a,b,c=8):
    return a+b+c
print(add(10,5))
print(add(10,5,5))
# Out:
# 23
# 20
