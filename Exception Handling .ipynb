# %%
value = [1,2,3,4,5]
print(value[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 value = [1,2,3,4,5]
# ----> 2 print(value[5])
#
# IndexError: list index out of range

# %%
num=7
print(num/0)
print('program executed')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 num=7
# ----> 2 print(num/0)
#       3 print('program executed')
#
# ZeroDivisionError: division by zero

# %%
try:
    num=7
    print(num/0)
except ZeroDivisionError:
    print("Program Executed")
# Out:
# Program Executed

# %%
try:
    file = open("xyz.txt","r")
except FileNotFoundError:
    print("file don't exist")
# Out:
# file don't exist

# %%
try:
    age=int(input("Enter your age"))
except ValueError:
    print("Enter integers only")
# Out:
# Enter your age qwerty
# Enter integers only

# %%
try:
    animal=int(input("Animal name"))
except ValueError:
    print("Enter Animal only here")
