# %%
name=["Akshaya","Asmitha","Lily","Ananya"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# Akshaya
# Asmitha
# Lily
# Ananya

# %%
num=[7,77,777,7777]
l=iter(num)
print(next(l))
print(next(l))
print(next(l))
print(next(l))
# Out:
# 7
# 77
# 777
# 7777

# %%
food=["Pizza","Pasta","Biryani","Burger"]
f=iter(food)
print(next(f))
print(next(f))
print(next(f))
print(next(f))
# Out:
# Pizza
# Pasta
# Biryani
# Burger

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
