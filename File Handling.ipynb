# %%
file = open("demo.txt" ,"r")
file.close()

# %%
file = open("demo.txt","w")
file.write("Hello Student")
file.close()

# %%
file= open("demo.txt","r")
Content=file.read()
print(Content)
file.close()
# Out:
# Hello Student
