# %%
print(7+7)
print('Akshaya' + 'Rao')
# Out:
# 14
# AkshayaRao

# %%
class Student :
    def __init__(self,marks):
        self.marks = marks

    def __add__(self,other):
         return self.marks+other.marks
        
s1=Student(77)
s2=Student(80)
print(s1+s2)
# Out:
# 157
