# %%
class Car:
    brand='Porshe'
    color='purple'
    speed='180'

car1=Car
print(car1.brand)
print(car1.color)
print(car1.speed)
# Out:
# Porshe
# purple
# 180

# %%
class Animals:
    type1='moneky'
    type2='rhino'
    type3='deer'

Ani=Animals
print(Ani.type1)
print(Ani.type2)
print(Ani.type3)
# Out:
# moneky
# rhino
# deer

# %%
class Student:
 def _init_(self,name,age):
    self.name=name
    self.age=age
s1=Student('Akshaya',19)
print(s1.name)
print(s1.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 5
#       3     self.name=name
#       4     self.age=age
# ----> 5 s1=Student('Akshaya',19)
#       6 print(s1.name)
#       7 print(s1.age)
#
# TypeError: Student() takes no arguments

# %%
class Student:
 def __init__(self,name,age):
     self.name = name
     self.age = age
s1=Student('Akshaya',19)
print(s1.name)
print(s1.age)
# Out:
# Akshaya
# 19
